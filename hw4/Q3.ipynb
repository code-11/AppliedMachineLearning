# %%
import matplotlib.pyplot as plt

# %matplotlib inline

loss = [0.0449, 0.027, 0.018, 0.015, 0.0131, 0.0114, 0.0103, 0.0097, 0.0089, 0.0085, 0.00829, 0.00802, 0.00787, 0.00755, 0.0072, 0.00708, 0.0073, 0.0069, 0.0068, 0.0068, 0.0067, 0.0064, 0.0063, 0.0063, 0.00618, 0.0063, 0.0062, 0.00606, 0.0059, 0.00581, 0.00573, 0.00568, 0.00565, 0.005722, 0.00557, 0.00547, 0.00548, 0.00539, 0.00543, 0.0053, 0.00515, 0.00518, 0.00515, 0.00515, 0.00526, 0.00506, 0.0052, 0.005188, 0.00508, 0.00496, 0.0049]
iterations = [99, 199, 299, 399, 499, 599, 699, 799, 899, 999, 1099, 1199, 1299, 1399, 1499, 1599, 1699, 1799, 1899, 1999, 2099, 2199, 2299, 2399, 2499, 2599, 2699, 2799, 2899, 2999, 3099, 3199, 3299, 3399, 3499, 3599, 3699, 3799, 3899, 3999, 4099, 4199, 4299, 4399, 4499, 4599, 4699, 4799, 4899, 4999, 5099]

print(loss[40])
plt.plot(iterations, loss, '.-')
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Loss versus Iteratoins")
# Out:
# 0.00515

# %%
lr = [0.01, 0.01,  0.0056, 0.00158, 0.000501, 0.00011]
i = [0, 1037, 1999, 3022, 4004, 5023]
l = [0.1, 0.00896, 0.006, 0.00405, 0.00369, 0.00362]

plt.plot(i, l, '.-')
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Loss versus Iteratoins with varrying Learning Rates")

# %%
layers = [8, 7, 6, 5, 4, 3, 2]
loss = [0.00829, 0.00779, 0.009, 0.0093, 0.012, 0.0176, 0.0267 ]

plt.plot(layers, loss, '.-')
plt.xlabel("Layers")
plt.ylabel("Loss")
plt.title("Loss versus Hidden Layers in Neural Net")

# %%
layers = [11, 10, 9, 8, 7, 6, 5, 4, 3, 2]
loss = [0.0107, 0.0102, 0.0101, 0.00829, 0.00779, 0.009, 0.0093, 0.012, 0.0176, 0.0267 ]

plt.plot(layers, loss, '.-')
plt.xlabel("Layers")
plt.ylabel("Loss")
plt.title("Loss versus Hidden Layers in Neural Net")
